# %% [markdown]
# W3A1: Input then print out revesed output (Eg: 1234 --> 4321)

# %%
from click import group
numbers=int(input())
listnum = list(map(int, str(numbers)))
reverselist=listnum[::-1]
substitute=0
for i in reverselist:
    substitute=substitute*10+i
print(substitute)
# Out:
# 987654321

# %% [markdown]
# W3A2: Input then swap variable with XOR bitwise(#"^")   this one --> ^

# %%
a, b = map(int,input().split())
a=a^b
b=a^b
a=a^b
print(a, b)
# Out:
# 10 5

# %% [markdown]
# W3A3

# %%
a= int(input())
if a>0 and a & (a-1)==0:
    print("True")
else:
    print("False")
# Out:
# TRUE

# %% [markdown]
# W3A4

# %%
a, b = map(int,input().split())
print(a//b)
# Out:
# 0

# %% [markdown]
# W3A5

# %%
import math
a, b = map(int,input().split())
c=math.ceil(a/b)
print(c)
# Out:
# 1

# %% [markdown]
# W3A6

# %%
a= int(input())
if a%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %% [markdown]
# W3A7

# %%
a= int(input())
b= int(input())
if a>0 and b>0:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# W3A8

# %%
a= str(input())
b= str(input())
if len(a)>len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# W3A9

# %%
a, b, c = map(int, (input().split()))
if a+b>c and a+c>b and b+c>a:
    print("Yes")

# %% [markdown]
# W3A10

# %%
a, b, c, d = map(int, (input().split()))
sub=0
if a>b and a>c and a>d:
    sub=a
    print(sub)
elif b>a and b>c and b>d:
    sub=b
    print(sub)
elif c>a and c>b and c>d:
    sub=c
    print(sub)
else:
    sub=d
    print(sub)
# Out:
# 52165413

# %% [markdown]
# W3A11

# %%
a,b,c = map(int, (input().split()))
if a==b and b==c:
    print("Tam giac deu")
elif a==b or b==c or a==c:
    print("Tam giac can")
elif a!=b and b!=c and a!=c and a+b>c and a+c>b and b+c>a:
    print("Tam giac thuong")
elif a+b<=c or a+c<=b or b+c<=a:
    print("Khong phai tam giac")
# Out:
# Scalene

# %% [markdown]
# W3A12

# %%
y=input()
if y%4==0 and y%100!=0 or y%400==0:
    print("Yes")
else:
    print("No")

# %% [markdown]
# W3A13

# %%
a=int(input())
b=0
if a<=50:
    b=a*1500
    print(b)
elif a>50 and a<=100:
    b=50*1500 + (a-50)*2000
    print(b)
elif a>100:
    b=50*1500 + 50*2000 + (a-100)*3000
    print(b)
# Out:
# 838000

# %% [markdown]
# W3A14

# %%
a, b = map(float,input().split())
#ax + b = 0 => x = -b/a
if a == 0:
    if b == 0:
        print("vo so nghiem")
    else:
        print("vo nghiem")
else:
    x = -b/a
    print(x)
# Out:
# vo so nghiem

# %% [markdown]
# W3A15

# %%
x=float(input())
if x>=8 and x<=10:
    print("Gioi")
elif x>=6.5 and x<8:
    print("Kha")
elif x>=5 and x<6.5:
    print("Trung binh")
else: 
    print("Yeu")
# Out:
# Yeu

# %% [markdown]
# W3A16

# %%
import time
a= float(input())
if a>0:
    tron_len=a+1
    tron_len=int(tron_len)
    tron_xuong=int(a)
elif a==0:
    print("Steam compression piston pressure cap removed.")
    time.sleep(1)
    print("Observed temporal vector calculation complete…")
    time.sleep(1)
    print("Transform Accumulated Past; maintain moment value… Launch")
    time.sleep(1)
    print("It's 0 0 0 btw ig")

else:
    tron_len=int(a)
    tron_xuong=a-1
    tron_xuong=int(tron_xuong)


if abs(tron_len-a)>=abs(tron_xuong-a):
    tron_gan=tron_xuong
else: 
    tron_gan=tron_len
if a!=0:
    print(f"{tron_len} {tron_xuong} {tron_gan}")
# Out:
# Steam compression piston pressure cap removed.
# Observed temporal vector calculation complete…
# Transform Accumulated Past; maintain moment value… Launch
# It's 0 0 0 btw ig

# %% [markdown]
# W3A17

# %%
a, b, c, d = map(float, (input().split()))
e= b/a
if b*e==c and c*e==d:
    print("Yes")
else:
    print("No")
# Out:
# Yes
